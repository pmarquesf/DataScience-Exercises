# %% [markdown]
# ##ATIVIDADE 3.6
# 1- Empregar ao máximo métodos de visualização gráfica estudados na Unidade 3 - Análise Exploratória e Estatística Descritiva  Baixar Unidade 3 - Análise Exploratória e Estatística Descritivae outros que julgar pertinente;

# %%
# !git clone "https://github.com/malegopc/DSBD"
# Out:
# fatal: destination path 'DSBD' already exists and is not an empty directory.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
tabela = pd.read_excel ('DSBD/Datasets/Video_games/venda_video_games.xlsx')
tabela
# Out:
#                                                     Nome Plataforma   Ano  \
# 0                                              Asteroids       2600  1980
# 1                                        Missile Command       2600  1980
# 2                                                Kaboom!       2600  1980
# 3                                               Defender       2600  1980
# 4                                                 Boxing       2600  1980
# ...                                                  ...        ...   ...
# 16292                                       Mighty No. 9       XOne  2016
# 16293                                 Resident Evil 4 HD       XOne  2016
# 16294                      Farming 2017 - The Simulation        PS4  2016
# 16295                                  Rugby Challenge 3       XOne  2016
# 16296  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...        PSV  2016
#
#            Gênero              Produtor    NA    EU    JP    RM  Global
# ...

# %%
#Gráfico de pizza acerca dos produtores de video-game
from pandas.core.internals import construction
union = ['Eletronic Arts','Activision', 'Namco', 'Ubisoft', 'Konami', 'Outras'] 
data = [26.89, 19.40, 18.64, 18.42, 16.53,00.01]
plt.pie(data, labels = union,colors=['Red','blue','Yellow','Orange','Pink','green'])


plt.title('Produtor:')
# Out:
# Text(0.5, 1.0, 'Produtor:')

# %%
sns.boxplot(data=tabela, x='Ano', y='Gênero')

# %%
#Mostra os diagrams de dispersão om suas respectivas retas de regressão entre todos os pares de variáveis.
sns.pairplot(tabela)

# %%
#Mostra a correlação entre todos os pares de variáveis
corrMatrix = tabela.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# 2 - Apresentar minimamente as seguintes análises ou informações:

# %% [markdown]
# I - Top 5 dos jogos mais vendidos (considerando todos os anos)

# %%
tabela['Nome'].value_counts()
# Out:
# Need for Speed: Most Wanted                                12
# FIFA 14                                                     9
# Ratatouille                                                 9
# LEGO Marvel Super Heroes                                    9
# Madden NFL 08                                               8
#                                                            ..
# Tony Hawk's American Wasteland (Old all region sales)       1
# Super Mario Strikers                                        1
# Buzz! The Music Quiz                                        1
# Dollar Dash                                                 1
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirube Kareru     1
# Name: Nome, Length: 11346, dtype: int64

# %% [markdown]
# II - Mostrar a distribuição de frequências (contagem) de todos os gêneros de jogos. Você deve apresentar uma listagem em ordem decrescente (dos gêneros de jogos mais lançados até os menos lançados). Apresente também um gráfico de barras (ou histograma) da distribuição (contagem) dos gêneros em ordem decrescente;

# %%
tabela['Gênero'].value_counts()
# Out:
# Action          3249
# Sports          2304
# Misc            1710
# Role-Playing    1469
# Shooter         1282
# Adventure       1253
# Racing          1226
# Platform         876
# Simulation       850
# Fighting         836
# Strategy         671
# Puzzle           571
# Name: Gênero, dtype: int64

# %%
ax = sns.countplot(x="Gênero", data=tabela)
plt.figure(figsize=(100, 200))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-92fb112e0f2a> in <module>()
# ----> 1 tabela.groupby(by=['Ano'])['Nome'].sum()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in sum(self, numeric_only, min_count)
#    1851                 min_count=min_count,
#    1852                 alias="add",
# -> 1853                 npfunc=np.sum,
#    1854             )
#    1855
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1366                 alt=npfunc,
#    1367                 numeric_only=numeric_only,
# -> 1368                 min_count=min_count,
#    1369             )
#    1370             return result.__finalize__(self.obj, method="groupby")
#
# ...
